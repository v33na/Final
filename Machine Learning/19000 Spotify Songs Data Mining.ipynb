# %%
import numpy as np
import csv
import json
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
import matplotlib.pyplot as mlp
import pandas as pd
from pandas import DataFrame

from sqlalchemy import create_engine

# %%
df_song = pd.read_csv('Resources/19000-spotify-songs/song_data.csv')
df_song = df_song.drop(['song_name'], axis=1)

df_info = pd.read_csv('Resources/19000-spotify-songs/song_info.csv')
Spotify_songs_df = pd.concat([df_song, df_info], axis=1)

Spotify_songs_df

patrick_list_df = pd.read_csv('19000-spotify-songs/Patrick_list.csv')
# df = df.drop('album_names', axis=1)

# %%
Spotify_songs_df = pd.merge(Spotify_songs_df, patrick_list_df, how='inner')
Spotify_songs_df
Spotify_songs_df['Artist_and_Track_Name'] = Spotify_songs_df['artist_name']+ ' - ' + Spotify_songs_df['song_name']
Spotify_songs_df = Spotify_songs_df.drop(['song_name', 'artist_name'], axis=1)
# Spot = Spotify_songs_df.dropna(axis=0, how='any')

Spotify_songs_df
# final = Spot.drop_duplicates(["Artist_and_Track_Name"])
# final
# Out:
#       song_popularity  song_duration_ms  acousticness  danceability  energy  \
# 0                  74            216933      0.026400         0.451   0.970
# 1                  81            199893      0.000504         0.581   0.887
# 2                  81            269000      0.017900         0.618   0.938
# 3                  71            227240      0.001360         0.659   0.778
# 4                  62            256600      0.007010         0.370   0.944
# 5                  77            187613      0.093800         0.567   0.795
# 6                  79            232533      0.872000         0.657   0.291
# 7                  28            303920      0.010200         0.440   0.932
# 8                  77            311106      0.000289         0.217   0.905
# 9                  11            262733      0.000194         0.582   0.597
# 10                 11            269373      0.000917         0.433   0.959
# ...

# %%
export_csv = Spotify_songs_df.to_csv('patrick_spotify_list.csv', index=False)
songs = pd.read_csv('patrick_spotify_list.csv')
songs
# Out:
#       song_popularity  song_duration_ms  acousticness  danceability  energy  \
# 0                  74            216933      0.026400         0.451   0.970
# 1                  81            199893      0.000504         0.581   0.887
# 2                  81            269000      0.017900         0.618   0.938
# 3                  71            227240      0.001360         0.659   0.778
# 4                  62            256600      0.007010         0.370   0.944
# 5                  77            187613      0.093800         0.567   0.795
# 6                  79            232533      0.872000         0.657   0.291
# 7                  28            303920      0.010200         0.440   0.932
# 8                  77            311106      0.000289         0.217   0.905
# 9                  11            262733      0.000194         0.582   0.597
# 10                 11            269373      0.000917         0.433   0.959
# ...
